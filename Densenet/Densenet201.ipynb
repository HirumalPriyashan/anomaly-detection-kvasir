# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Activation, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras import backend
from tensorflow.keras.preprocessing.image import img_to_array, ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import DenseNet201
from imutils import paths
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19004/3233329983.py in <module>
# ----> 1 from tensorflow.keras.models import Model
#       2 from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Activation, Flatten, Dense, Dropout, GlobalAveragePooling2D
#       3 from tensorflow.keras import backend
#       4 from tensorflow.keras.preprocessing.image import img_to_array, ImageDataGenerator
#       5 from tensorflow.keras.utils import to_categorical
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
datasetPath='..\kvasir-dataset'
categories=[
    'dyed-lifted-polyps', 
    'dyed-resection-margins',
    'esophagitis',
    'normal-cecum',
    'normal-pylorus',
    'normal-z-line',
    'polyps',
    'ulcerative-colitis'
]
EPOCHS = 25
Learing_Rate = 1e-3
Batch_Size = 32
img_rows = 160
img_cols = 160
img_size = (img_rows,img_cols)

# %%
def printProgressBar (iteration, total, prefix = '', suffix = '', decimals = 1, length = 100, fill = '█', printEnd = "\r"):
    percent = ("{0:." + str(decimals) + "f}").format(100 * (iteration / float(total)))
    filledLength = int(length * iteration // total)
    bar = fill * filledLength + '-' * (length - filledLength)
    print(f'\r{prefix} |{bar}| {percent}% {suffix}', end = printEnd)
    if iteration == total: 
        print()

# %%
data = []
labels = []

print("[INFO] loading images...")
imagePaths = sorted(list(paths.list_images(datasetPath)))
random.seed(42)
random.shuffle(imagePaths)

printProgressBar(0, len(imagePaths), prefix = 'Progress:', suffix = 'Complete', length = 50)
for i,imagePath in enumerate(imagePaths):
    image = cv2.imread(imagePath)
    image = cv2.resize(image, img_size)
    image = img_to_array(image)
    data.append(image)
    label = imagePath.split(os.path.sep)[-2]
    label = categories.index(label)
    labels.append(label)
    printProgressBar(i + 1, len(imagePaths), prefix = 'Progress:', suffix = 'Complete', length = 50)

print("[INFO] loading images completed...")
# Out:
# [INFO] loading images...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# [INFO] loading images completed...

# %%
data = np.array(data, dtype="float") 
labels = np.array(labels)

(trainX, testX, trainY, testY) = train_test_split(data,labels, test_size=0.25, random_state=42)

trainY = to_categorical(trainY, num_classes=8)
testY = to_categorical(testY, num_classes=8)

# %%
print ("number of training examples = " + str(trainX.shape[0]))
print ("number of test examples = " + str(testX.shape[0]))
print ("X_train shape: " + str(trainX.shape))
print ("Y_train shape: " + str(trainY.shape))
print ("X_test shape: " + str(testX.shape))
print ("Y_test shape: " + str(testY.shape))
# Out:
# number of training examples = 3000
# number of test examples = 1000
# X_train shape: (3000, 160, 160, 3)
# Y_train shape: (3000, 8)
# X_test shape: (1000, 160, 160, 3)
# Y_test shape: (1000, 8)

# %%
generator = ImageDataGenerator(
    rotation_range=30, 
    width_shift_range=0.1,
    height_shift_range=0.1, 
    shear_range=0.2, 
    zoom_range=0.2,
    horizontal_flip=True, 
    fill_mode="nearest"
)

# %%
def buildModel(width, height, depth, classes):
    inputShape = (height, width, depth)
    if backend.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
    base_model = DenseNet201(
        input_shape=inputShape,
        include_top=False,
        weights='imagenet'
    )
    inputs = tf.keras.layers.Input([height, width, 3], dtype = tf.float32)
    model = tf.keras.applications.densenet.preprocess_input(inputs)
    base_model.trainable = True
    fine_tune_at = 600
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False
    model = base_model(model)
    model = GlobalAveragePooling2D()(model)
    model = Dense(1024,activation='relu')(model)
    model = Dropout(0.2)(model)
    model = Dense(512,activation='relu')(model)
    model = Dense(classes,activation='softmax')(model)
    model = Model(inputs = inputs, outputs = model)
    return model

# %%
print("[INFO] compiling model...")
model = buildModel(width=img_cols, height=img_rows, depth=3, classes=8)
model.summary()
# Out:
# [INFO] compiling model...
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 160, 160, 3)]     0
# _________________________________________________________________
# tf_op_layer_RealDiv_2 (Tenso [(None, 160, 160, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd_1 (Tenso [(None, 160, 160, 3)]     0
# _________________________________________________________________
# tf_op_layer_RealDiv_3 (Tenso [(None, 160, 160, 3)]     0
# _________________________________________________________________
# densenet201 (Functional)     (None, 5, 5, 1920)        18321984
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1920)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1967104
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 4104
# =================================================================
# Total params: 20,817,992
# Trainable params: 6,301,448
# Non-trainable params: 14,516,544
# _________________________________________________________________

# %%
opt = Adam(lr=Learing_Rate, decay=Learing_Rate / EPOCHS)
model.compile(
    loss="categorical_crossentropy", 
    optimizer=opt, 
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.SpecificityAtSensitivity(0.5,name="specificity")
    ]
)

# %%
print("[INFO] training network...")
history = model.fit(
    x=generator.flow(trainX, trainY, batch_size=Batch_Size),
    validation_data=(testX, testY), 
    steps_per_epoch=len(trainX) // Batch_Size,
    epochs=EPOCHS, 
    verbose=1)
print("[INFO] training network completed...")
# Out:
# [INFO] training network...
# Epoch 1/25
# 93/93 [==============================] - 463s 5s/step - loss: 0.6371 - accuracy: 0.7709 - precision: 0.8094 - recall: 0.7325 - specificity: 0.9931 - val_loss: 0.4745 - val_accuracy: 0.8550 - val_precision: 0.8616 - val_recall: 0.8530 - val_specificity: 0.9977
# Epoch 2/25
# 93/93 [==============================] - 453s 5s/step - loss: 0.3519 - accuracy: 0.8679 - precision: 0.8788 - recall: 0.8548 - specificity: 0.9987 - val_loss: 0.8843 - val_accuracy: 0.7770 - val_precision: 0.7899 - val_recall: 0.7670 - val_specificity: 0.9909
# Epoch 3/25
# 93/93 [==============================] - 454s 5s/step - loss: 0.2979 - accuracy: 0.8912 - precision: 0.8979 - recall: 0.8831 - specificity: 0.9992 - val_loss: 0.3924 - val_accuracy: 0.8770 - val_precision: 0.8781 - val_recall: 0.8720 - val_specificity: 0.9986
# Epoch 4/25
# 93/93 [==============================] - 453s 5s/step - loss: 0.2659 - accuracy: 0.9026 - precision: 0.9084 - recall: 0.8956 - specificity: 0.9994 - val_loss: 0.4263 - val_accuracy: 0.8660 - val_precision: 0.8712 - val_recall: 0.8590 - val_specificity: 0.9981
# Epoch 5/25
# 93/93 [==============================] - 432s 5s/step - loss: 0.2250 - accuracy: 0.9178 - precision: 0.9218 - recall: 0.9097 - specificity: 0.9997 - val_loss: 0.4504 - val_accuracy: 0.8570 - val_precision: 0.8584 - val_recall: 0.8550 - val_specificity: 0.9970
# Epoch 6/25
# 93/93 [==============================] - 422s 5s/step - loss: 0.2173 - accuracy: 0.9201 - precision: 0.9257 - recall: 0.9158 - specificity: 0.9997 - val_loss: 0.3841 - val_accuracy: 0.8910 - val_precision: 0.8937 - val_recall: 0.8830 - val_specificity: 0.9991
# Epoch 7/25
# 93/93 [==============================] - 419s 5s/step - loss: 0.1951 - accuracy: 0.9343 - precision: 0.9391 - recall: 0.9292 - specificity: 0.9997 - val_loss: 0.3452 - val_accuracy: 0.9010 - val_precision: 0.9028 - val_recall: 0.9010 - val_specificity: 0.9984
# Epoch 8/25
# 93/93 [==============================] - 415s 4s/step - loss: 0.1819 - accuracy: 0.9292 - precision: 0.9342 - recall: 0.9276 - specificity: 0.9998 - val_loss: 0.2808 - val_accuracy: 0.9000 - val_precision: 0.9018 - val_recall: 0.9000 - val_specificity: 0.9994
# Epoch 9/25
# 93/93 [==============================] - 417s 4s/step - loss: 0.1450 - accuracy: 0.9431 - precision: 0.9452 - recall: 0.9417 - specificity: 0.9999 - val_loss: 0.3033 - val_accuracy: 0.9010 - val_precision: 0.9019 - val_recall: 0.9010 - val_specificity: 0.9991
# Epoch 10/25
# 93/93 [==============================] - 430s 5s/step - loss: 0.1606 - accuracy: 0.9434 - precision: 0.9452 - recall: 0.9410 - specificity: 0.9998 - val_loss: 0.2799 - val_accuracy: 0.9030 - val_precision: 0.9074 - val_recall: 0.9010 - val_specificity: 0.9997
# Epoch 11/25
# 93/93 [==============================] - 429s 5s/step - loss: 0.1206 - accuracy: 0.9511 - precision: 0.9514 - recall: 0.9501 - specificity: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9050 - val_precision: 0.9055 - val_recall: 0.9010 - val_specificity: 0.9979
# Epoch 12/25
# 93/93 [==============================] - 424s 5s/step - loss: 0.1442 - accuracy: 0.9474 - precision: 0.9493 - recall: 0.9461 - specificity: 0.9997 - val_loss: 0.3153 - val_accuracy: 0.8970 - val_precision: 0.8985 - val_recall: 0.8940 - val_specificity: 0.9993
# Epoch 13/25
# 93/93 [==============================] - 414s 4s/step - loss: 0.1305 - accuracy: 0.9501 - precision: 0.9520 - recall: 0.9485 - specificity: 0.9998 - val_loss: 0.2934 - val_accuracy: 0.9150 - val_precision: 0.9159 - val_recall: 0.9150 - val_specificity: 0.9984
# Epoch 14/25
# 93/93 [==============================] - 417s 4s/step - loss: 0.1296 - accuracy: 0.9518 - precision: 0.9542 - recall: 0.9485 - specificity: 0.9999 - val_loss: 0.4173 - val_accuracy: 0.8790 - val_precision: 0.8803 - val_recall: 0.8750 - val_specificity: 0.9976
# Epoch 15/25
# 93/93 [==============================] - 417s 4s/step - loss: 0.1158 - accuracy: 0.9569 - precision: 0.9578 - recall: 0.9559 - specificity: 0.9999 - val_loss: 0.3052 - val_accuracy: 0.9040 - val_precision: 0.9047 - val_recall: 0.9020 - val_specificity: 0.9990
# Epoch 16/25
# 93/93 [==============================] - 414s 4s/step - loss: 0.1240 - accuracy: 0.9562 - precision: 0.9568 - recall: 0.9559 - specificity: 0.9998 - val_loss: 0.5334 - val_accuracy: 0.8360 - val_precision: 0.8379 - val_recall: 0.8320 - val_specificity: 0.9976
# Epoch 17/25
# 93/93 [==============================] - 417s 4s/step - loss: 0.1286 - accuracy: 0.9511 - precision: 0.9536 - recall: 0.9488 - specificity: 0.9999 - val_loss: 0.3762 - val_accuracy: 0.8980 - val_precision: 0.8996 - val_recall: 0.8960 - val_specificity: 0.9977
# Epoch 18/25
# 93/93 [==============================] - 414s 4s/step - loss: 0.1188 - accuracy: 0.9575 - precision: 0.9604 - recall: 0.9562 - specificity: 0.9998 - val_loss: 0.3813 - val_accuracy: 0.8960 - val_precision: 0.8994 - val_recall: 0.8940 - val_specificity: 0.9973
# Epoch 19/25
# 93/93 [==============================] - 413s 4s/step - loss: 0.1165 - accuracy: 0.9589 - precision: 0.9602 - recall: 0.9586 - specificity: 0.9998 - val_loss: 0.3396 - val_accuracy: 0.8920 - val_precision: 0.8964 - val_recall: 0.8910 - val_specificity: 0.9974
# Epoch 20/25
# 93/93 [==============================] - 412s 4s/step - loss: 0.1082 - accuracy: 0.9629 - precision: 0.9645 - recall: 0.9609 - specificity: 0.9998 - val_loss: 0.3374 - val_accuracy: 0.9060 - val_precision: 0.9085 - val_recall: 0.9030 - val_specificity: 0.9980
# Epoch 21/25
# 93/93 [==============================] - 413s 4s/step - loss: 0.0959 - accuracy: 0.9646 - precision: 0.9652 - recall: 0.9633 - specificity: 0.9998 - val_loss: 0.4152 - val_accuracy: 0.9000 - val_precision: 0.9034 - val_recall: 0.8980 - val_specificity: 0.9960
# Epoch 22/25
# 93/93 [==============================] - 415s 4s/step - loss: 0.0974 - accuracy: 0.9643 - precision: 0.9665 - recall: 0.9636 - specificity: 0.9999 - val_loss: 0.4460 - val_accuracy: 0.8930 - val_precision: 0.8964 - val_recall: 0.8910 - val_specificity: 0.9961
# Epoch 23/25
# 93/93 [==============================] - 418s 4s/step - loss: 0.0774 - accuracy: 0.9730 - precision: 0.9737 - recall: 0.9724 - specificity: 0.9999 - val_loss: 0.3247 - val_accuracy: 0.9020 - val_precision: 0.9047 - val_recall: 0.9020 - val_specificity: 0.9974
# Epoch 24/25
# 93/93 [==============================] - 419s 5s/step - loss: 0.0807 - accuracy: 0.9730 - precision: 0.9740 - recall: 0.9717 - specificity: 0.9998 - val_loss: 0.4808 - val_accuracy: 0.8920 - val_precision: 0.8964 - val_recall: 0.8910 - val_specificity: 0.9959
# Epoch 25/25
# 93/93 [==============================] - 417s 4s/step - loss: 0.0787 - accuracy: 0.9747 - precision: 0.9757 - recall: 0.9734 - specificity: 0.9999 - val_loss: 0.3596 - val_accuracy: 0.9050 - val_precision: 0.9075 - val_recall: 0.9030 - val_specificity: 0.9979
# [INFO] training network completed...

# %%
print("[INFO] saving model...")
model.save('Model_DenseNet_201.model', save_format="h5")
print("[INFO] model saved")
# Out:
# [INFO] saving model...
# [INFO] model saved

# %%
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Validation Accuracy")
plt.xlabel("Epoch No")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
plt.savefig('plot_DenseNet_201.png')

# %%
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epoch No")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
plt.show()
plt.savefig('plot_DenseNet201_Accuracy.png')

# %%
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epoch No")
plt.ylabel("Loss")
plt.legend(loc="lower left")
plt.show()
plt.savefig('plot_DenseNet201_Loss.png')

# %%
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), history.history["precision"], label="train_precision")
plt.plot(np.arange(0, N), history.history["recall"], label="train_recall")
plt.plot(np.arange(0, N), history.history["specificity"], label="train_specificity")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, N), history.history["val_precision"], label="val_precision")
plt.plot(np.arange(0, N), history.history["val_recall"], label="val_recall")
plt.plot(np.arange(0, N), history.history["val_specificity"], label="val_specificity")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_accuracy")
plt.title("Training Metrics")
plt.xlabel("Epoch No")
plt.ylabel("Value")
plt.legend(loc="lower left")
plt.show()
plt.savefig('plot_DenseNet_201_metrics.png')
